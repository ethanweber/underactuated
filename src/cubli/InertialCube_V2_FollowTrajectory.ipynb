# %%
import math
import numpy as np
import time, random
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML
from pydrake.math import sin, cos
from pydrake.all import *
from underactuated import (FindResource, PlanarRigidBodyVisualizer)

# %%
# %reload_ext autoreload
# %autoreload 2
from dynamics_nd import *

# %%
vis = MeshcatCubeVisualizer()
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/

# %%
traj, input_traj, force_traj, time_array = periodic_motion()
# Out:
# Number of decision vars 859
# SolutionResult.kSolutionFound

# %%
dimension = 2

# %%
# trajectory found
dt = time_array[1] - time_array[0]
for i in range(len(traj)):
    vis.draw_transformation(traj[i,:],dimension)
    time.sleep(dt)

# %%
x, u, f = qp_controller(traj[0], traj[1], 0.1, dimension)
# Out:
# SolutionResult.kSolutionFound

# %%
u
# Out:
# array([1.82736044])

# %%
# %reload_ext autoreload
# %autoreload 2
from plotting import *

# %%
plot_states(traj, time_array, dimension)

# %%
plot_vels(traj, time_array, dimension)

# %%
input_plot(input_traj, time_array, dimension)

# %%
ground_force_plot(force_traj, time_array, dimension)

# %%
# simulate controller to follow the trajectory computed

# %%
dim = dimension
current_state = traj[0,:].copy()
vis.draw_transformation(current_state, dim)

# %%
# code to test a trajectory
dt = time_array[1] - time_array[0]
for i in range(1, len(traj[:4])):
    desired_state = traj[i].copy()
    x, u, f = qp_controller(current_state, desired_state, dt, dim)
    current_state += get_nd_dynamics(current_state,u,f,dim)*dt
    vis.draw_transformation(current_state,dim)
    break
    time.sleep(dt)
# Out:
# -------------------------------------------------------------------
# TypeError                         Traceback (most recent call last)
# <ipython-input-64-3d5d7edcbcef> in <module>()
#       3 for i in range(1, len(traj[:4])):
#       4     desired_state = traj[i].copy()
# ----> 5     x, u, f = qp_controller(current_state, desired_state, dt, dim)
#       6     current_state += get_nd_dynamics(current_state,u,f,dim)*dt
#       7     vis.draw_transformation(current_state,dim)
#
# /Users/ethanweber/Documents/MIT_Classes/Sophomore_Spring2018/6.832/underactuated/src/cubli/dynamics_nd.pyc in qp_controller(current_state, desired_state, dt, dim)
#     519     pos_diff = state - np.asarray(desired_state)
#     520     # pos = pos_diff.dot(pos_diff)
# --> 521     mp.AddCost(pos_diff[0])
#     522
#     523     print(mp.Solve())
#
# TypeError: AddCost(): incompatible function arguments. The following argument types are supported:
#     1. (self: pydrake.solvers._mathematicalprogram_py.MathematicalProgram, func: function, vars: numpy.ndarray[object[m, 1]], description: unicode = u'') -> drake::solvers::Binding<drake::solvers::Cost>
#
# Invoked with: <pydrake.solvers._mathematicalprogram_py.MathematicalProgram object at 0x114547670>, <Expression "(1.03561552549237e-09 + x(0) + 0.29411764705882354 * x(4))">

# %%
current_state
# Out:
# array([ 1.74903722e-04, -6.29288385e-05, -1.88289184e-04, -7.08197300e-02,
#        -1.24739680e-02,  4.40500697e+01, -2.47401311e-04,  1.48731706e-01])

# %%
traj[1]
# Out:
# array([-1.03561553e-09,  1.03561569e-09,  2.07123135e-09, -7.08481094e-02,
#        -4.06016683e-05, -1.07371861e-04, -2.47401315e-04,  1.48731706e-01])

# %%
# # code to test a trajectory
# sec = 0.5 # seconds
# steps_per_sec = 100.0 # discrete steps in a second
# num_steps = sec*steps_per_sec # total number of steps
# sec_per_step = sec/num_steps # number of seconds per step
# for t in np.linspace(0,sec,num_steps):
#     x, u, f = qp_controller(current_state, desired_state, sec_per_step, dim)
#     current_state += get_nd_dynamics(current_state,u,f,dim)*sec_per_step
#     vis.draw_transformation(current_state, dim)
#     time.sleep(sec_per_step)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound
# SolutionResult.kSolutionFound

# %%
# dim = 3
# angle = 0.0
# angle_vel = 0.0 # 5.0
# current_state = get_nd_state((0,0.0,angle,0.0,0.,0.,angle_vel,00.0), dim)
# vis.draw_transformation(current_state, dim)

# %%
# # code to simulate dynamics
# sec = 0.5 # seconds
# steps_per_sec = 50.0 # discrete steps in a second
# num_steps = sec*steps_per_sec # total number of steps
# sec_per_step = sec/num_steps # number of seconds per step
# for t in np.linspace(0,sec,num_steps):
#     torque = [0.0]
#     force = np.asarray([0.,0.,0.,0.,0.,0.,0.,0.])
#     current_state += get_nd_dynamics(current_state,torque,force,dim)*sec_per_step
# #     current_state = contact_next_state(current_state,torque,sec_per_step,dim)
#     vis.draw_transformation(current_state, dim)
#     time.sleep(sec_per_step)
